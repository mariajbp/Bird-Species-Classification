# %% [markdown]
# # Classify 250 Bird Species

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from datetime import datetime
import matplotlib.pyplot as plt
from keras.callbacks import TensorBoard
from keras.callbacks import ModelCheckpoint, EarlyStopping
###
from keras.preprocessing.image import load_img,img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
###
from keras.optimizers import SGD, RMSprop, Adam, Adagrad
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, BatchNormalization, Dropout
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report, confusion_matrix

# %%
from google.colab import drive
drive.mount('/content/drive')

dirs = os.listdir('/content/drive/My Drive/TPCN')
print(dirs)
# Out:
# Mounted at /content/drive
# ['resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5', 'dataset.zip', 'datasetttt', 'weights.best.hdf5']

# %%
# !unzip -q '/content/drive/My Drive/TPCN/dataset.zip'

# %%
trainDirectory = os.listdir('dataset/train')
species = trainDirectory
trainLabels = species
print(trainLabels)
# Out:
# ['OYSTER CATCHER', 'FLAMINGO', 'HOOPOES', 'IMPERIAL SHAQ', 'GUINEAFOWL', 'SUPERB STARLING', 'PELICAN', 'INDIAN BUSTARD', 'GRAY CATBIRD', 'RED HEADED WOODPECKER', 'GAMBELS QUAIL', 'JAVA SPARROW', 'SORA', 'RAZORBILL', 'WILSONS BIRD OF PARADISE', 'OKINAWA RAIL', 'SAND MARTIN', 'FLAME TANAGER', 'PURPLE MARTIN', 'SRI LANKA BLUE MAGPIE', 'EASTERN TOWEE', 'GRAY PARTRIDGE', 'AFRICAN CROWNED CRANE', 'RUFUOS MOTMOT', 'HOUSE SPARROW', 'CUBAN TODY', 'ANNAS HUMMINGBIRD', 'VENEZUELIAN TROUPIAL', 'NORTHERN MOCKINGBIRD', 'BAR-TAILED GODWIT', 'RED HONEY CREEPER', 'KILLDEAR', 'OSPREY', 'EURASIAN GOLDEN ORIOLE', 'ROSY FACED LOVEBIRD', 'INDIAN PITTA', 'ALEXANDRINE PARAKEET', 'CALIFORNIA CONDOR', 'WOOD DUCK', 'BLACK-NECKED GREBE', 'BARN SWALLOW', 'GREEN JAY', 'PUFFIN', 'CHUKAR PARTRIDGE', 'CROWNED PIGEON', 'CARMINE BEE-EATER', 'BANANAQUIT', 'BOBOLINK', 'BLACK SWAN', 'RAINBOW LORIKEET', 'COMMON STARLING', 'MALLARD DUCK', 'NICOBAR PIGEON', 'MALEO', 'LONG-EARED OWL', 'SNOWY OWL', 'ANTBIRD', 'D-ARNAUDS BARBET', 'BALTIMORE ORIOLE', 'COUCHS KINGBIRD', 'WHITE TAILED TROPIC', 'GLOSSY IBIS', 'FIRE TAILLED MYZORNIS', 'PARUS MAJOR', 'PARADISE TANAGER', 'GOLDEN PIPIT', 'PHILIPPINE EAGLE', 'TRUMPTER SWAN', 'NORTHERN BALD IBIS', 'HOATZIN', 'CAPE MAY WARBLER', 'TOWNSENDS WARBLER', 'SHORT BILLED DOWITCHER', 'ROUGH LEG BUZZARD', 'AMERICAN GOLDFINCH', 'ROCK DOVE', 'INCA TERN', 'GOLDEN EAGLE', 'BLACK VULTURE', 'MASKED LAPWING', 'CINNAMON TEAL', 'EMU', 'PINK ROBIN', 'BARN OWL', 'GOLDEN PHEASANT', 'FRIGATE', 'HOUSE FINCH', 'MARABOU STORK', 'CASPIAN TERN', 'GOULDIAN FINCH', 'ASIAN CRESTED IBIS', 'AM
MMON GRACKLE', 'BARRED PUFFBIRD', 'CASSOWARY', 'PURPLE GALLINULE', 'MANDRIN DUCK', 'RED FACED WARBLER', 'JABIRU', 'VERMILION FLYCATHER', 'DARK EYED JUNCO', 'CRESTED NUTHATCH', 'RING-NECKED PHEASANT', 'TEAL DUCK', 'INDIGO BUNTING', 'GOLDEN CHLOROPHONIA', 'COCKATOO', 'BLACK THROATED ...

# %%
nSpecies = len(np.unique(species))
print('Number of species for train:', nSpecies)
# Out:
# Number of species for train: 250

# %%
testSpecies = os.listdir('dataset/test')
testLabels = testSpecies
print('Number of test species:',len(np.unique(testSpecies)))

valid = os.listdir('dataset/valid')
validationLabels = valid
print('Number of validation species:',len(np.unique(valid)))
# Out:
# Number of test species: 250
# Number of validation species: 250

# %% [markdown]
# # VGG16

# %%
from keras.applications.vgg16 import preprocess_input

#Creating generator for Training DataSet
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input,
                                   shear_range=0.1,
                                   zoom_range=0.1,
                                   horizontal_flip=True)

trainData = train_datagen.flow_from_directory('dataset/train', target_size=(224, 224), batch_size=64, class_mode='categorical')

#Creating generator for Validation DataSet
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
validData = val_datagen.flow_from_directory('dataset/valid', target_size=(224, 224), batch_size=32, class_mode='categorical')

#Creating generator for Test DataSet
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
testData = test_datagen.flow_from_directory('dataset/test', target_size=(224, 224), batch_size=32, class_mode='categorical', shuffle = False)
# Out:
# Found 35215 images belonging to 250 classes.
# Found 1250 images belonging to 250 classes.
# Found 1250 images belonging to 250 classes.

# %%
#instantiate a base model with pre-trained weigts.
base_model=keras.applications.VGG16(
    include_top=False,
    weights="imagenet",
    input_shape=(224,224,3))


#freeze the base model
base_model.trainable = False


#Create new model on top
from keras.models import Sequential
from keras.layers import Dense,Flatten,Dropout
model=Sequential()
model.add(base_model)
model.add(Flatten())
model.add(Dense(2048,activation='relu',kernel_initializer='he_normal'))
model.add(Dropout(0.35))
model.add(Dense(2048,activation='relu',kernel_initializer='he_normal'))
model.add(Dropout(0.35))
model.add(Dense(250,activation='softmax',kernel_initializer='glorot_normal'))

model.summary()

#Train the model on new data.
model.compile(optimizer=keras.optimizers.Adam(1e-4),loss='categorical_crossentropy',metrics=['accuracy'])
history = model.fit(trainData,epochs=40,validation_data=validData,workers=10,use_multiprocessing=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2048)              51382272
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2048)              4196352
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 250)               512250
# =================================================================
# Total params: 70,805,562
# Trainable params: 56,090,874
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/40
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 550/551 [============================>.] - ETA: 0s - loss: 16.8967 - accuracy: 0.0329WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 551/551 [==============================] - ETA: 0s - loss: 16.8816 - accuracy: 0.0330WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 551/551 [==============================] - 385s 686ms/step - loss: 16.8666 - accuracy: 0.0330 - val_loss: 3.8761 - val_accuracy: 0.2712
# Epoch 2/40
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 550/551 [============================>.] - ETA: 0s - loss: 4.2285 - accuracy: 0.2142WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 551/551 [==============================] - ETA: 0s - loss: 4.2279 - accuracy: 0.2143WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 551/551 [==============================] - 376s 670ms/step - loss: 4.2273 - accuracy: 0.2144 - val_loss: 1.9309 - val_accuracy: 0.5944
# Epoch 3/40
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 550/551 [============================>.] - ETA: 0s - loss: 2.9483 - accuracy: 0.4192WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 551/551 [==============================] - ETA: 0s - loss: 2.9480 - accuracy: 0.4192WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 551/551 [==============================] - 376s 669ms/step - loss: 2.9477 - accuracy: 0.4193 - val_loss: 1.1087 - val_accuracy: 0.7424
# Epoch 4/40
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 550/551 [============================>.] - ETA: 0s - loss: 2.2734 - accuracy: 0.5480WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 551/551 [==============================] - ETA: 0s - loss: 2.2733 - accuracy: 0.5480WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 551/551 [==============================] - 375s 667ms/step - loss: 2.2731 - accuracy: 0.5480 - val_loss: 0.8257 - val_accuracy: 0.7968
# Epoch 5/40
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 550/551 [============================>.] - ETA: 0s - loss: 1.8691 - accuracy: 0.6222WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 551/551 [==============================] - ETA: 0s - loss: 1.8691 - accuracy: 0.6222WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 551/551 [==============================] -
ARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 551/551 [==============================] - 374s 666ms/step - loss: 0.3830 - accuracy: 0.9332 - val_loss: 0.2968 - val_accuracy: 0.9456
# Epoch 38/40
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 550/551 [============================>.] - ETA: 0s - loss: 0.3833 - accuracy: 0.9321WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 551/551 [==============================] - ETA: 0s - loss: 0.3832 - accuracy: 0.9321WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 551/551 [==============================] - 376s 670ms/step - loss: 0.3832 - accuracy: 0.9321 - val_loss: 0.3554 - val_accuracy: 0.9464
# Epoch 39/40
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 550/551 [============================>.] - ETA: 0s - loss: 0.3537 - accuracy: 0.9359WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 551/551 [==============================] - ETA: 0s - loss: 0.3537 - accuracy: 0.9359WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 551/551 [==============================] - 376s 669ms/step - loss: 0.3537 - accuracy: 0.9359 - val_loss: 0.2721 - val_accuracy: 0.9480
# Epoch 40/40
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 550/551 [============================>.] - ETA: 0s - loss: 0.3591 - accuracy: 0.9363WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 551/551 [==============================] - ETA: 0s - loss: 0.3591 - accuracy: 0.9363WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 551/551 [==============================] - 376s 670ms/step - loss: 0.3591 - accuracy: 0.9363 - val_loss: 0.3010 - val_accuracy: 0.9464

# %%
#plot accuracy vs epoch
plt.plot(history.history['accuracy'], color='magenta')
plt.plot(history.history['val_accuracy'], color='darkorchid')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot loss values vs epoch
plt.plot(history.history['loss'], color='magenta')
plt.plot(history.history['val_loss'], color='darkorchid')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Evaluate against test data.
testVGG16 = model.evaluate(testData, verbose=1)
print('Test loss:', testVGG16 [0])
print('Test accuracy:', testVGG16[1])
# Out:
# 40/40 [==============================] - 3s 86ms/step - loss: 0.2001 - accuracy: 0.9656
# Test loss: 0.2001117318868637
# Test accuracy: 0.9656000137329102

# %%
predictVGG16 = model.predict(testData)

print(classification_report(testData.classes, tf.argmax(predictVGG16, axis=-1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       0.83      1.00      0.91         5
#            2       0.83      1.00      0.91         5
#            3       1.00      1.00      1.00         5
#            4       1.00      1.00      1.00         5
#            5       1.00      1.00      1.00         5
#            6       1.00      1.00      1.00         5
#            7       0.80      0.80      0.80         5
#            8       1.00      1.00      1.00         5
#            9       0.83      1.00      0.91         5
#           10       1.00      0.80      0.89         5
#           11       1.00      1.00      1.00         5
#           12       1.00      1.00      1.00         5
#           13       1.00      1.00      1.00         5
#           14       1.00      1.00      1.00         5
#           15       1.00      1.00      1.00         5
#           16       1.00      1.00      1.00         5
#           17       1.00      1.00      1.00         5
#           18       1.00      1.00      1.00         5
#           19       1.00      1.00      1.00         5
#           20       1.00      1.00      1.00         5
#           21       0.83      1.00      0.91         5
#           22       1.00      0.80      0.89         5
#           23       1.00      1.00      1.00         5
#           24       1.00      1.00      1.00         5
#           25       1.00      0.80      0.89         5
#           26       1.00      0.80      0.89         5
#           27       1.00      1.00      1.00         5
#           28       1.00      0.80      0.89         5
#           29       1.00      1.00      1.00         5
#           30       1.00      1.00      1.00         5
#           31       1.00      1.00      1.00         5
#           32       1.00      1.00      1.00         5
#           33       1.00      1.00      1.00         5
#           34       1.00      1.00      1.00         5
#           35       1.00      1.00      1.00         5
#           36       1.00      1.00      1.00         5
#           37       1.00      0.80      0.89         5
#           38       1.00      1.00      1.00         5
#           39       1.00      1.00      1.00         5
#           40       1.00      1.00      1.00         5
#           41       1.00      1.00      1.00         5
#           42       1.00      1.00      1.00         5
#           43       1.00      1.00      1.00         5
#           44       1.00      0.80      0.89         5
#           45       1.00      0.80      0.89         5
#           46       1.00      1.00      1.00         5
#           47       0.71      1.00      0.83         5
#           48       1.00      1.00      1.00         5
#           49       1.00      1.00      1.00         5
#           50       1.00      1.00      1.00         5
#          225       1.00      1.00      1.00         5
#          226       0.71      1.00      0.83         5
#          227       1.00      1.00      1.00         5
#          228       1.00      0.80      0.89         5
#          229       1.00      0.80      0.89         5
#          230       1.00      1.00      1.00         5
#          231       1.00      1.00      1.00         5
#          232       1.00      1.00      1.00         5
#          233       1.00      1.00      1.00         5
#          234       1.00      1.00      1.00         5
#          235       1.00      1.00      1.00         5
#          236       0.83      1.00      0.91         5
#          237       1.00      1.00      1.00         5
#          238       1.00      1.00      1.00         5
#          239       1.00      1.00      1.00         5
#          240       1.00      1.00      1.00         5
#          241       0.83      1.00      0.91         5
#          242       1.00      1.00      1.00         5
#          243       1.00      1.00      1.00         5
#          244       0.83      1.00      0.91         5
#          245       1.00      1.00      1.00         5
#          246       1.00      1.00      1.00         5
#          247       1.00      0.80      0.89         5
#          248       1.00      1.00      1.00         5
#          249       1.00      0.80      0.89         5
#
#     accuracy                           0.97      1250
#    macro avg       0.97      0.97      0.96      1250
# weighted avg       0.97      0.97      0.96      1250

# %%
for i, prediction in enumerate(predictVGG16):
    predicted_value = tf.argmax(prediction)
    label = predicted_value.numpy()
    print('Predicted a %d. Real value is %d.' %(predicted_value, testData.classes[i]))
# Out:
# Predicted a 0. Real value is 0.
# Predicted a 0. Real value is 0.
# Predicted a 0. Real value is 0.
# Predicted a 0. Real value is 0.
# Predicted a 0. Real value is 0.
# Predicted a 1. Real value is 1.
# Predicted a 1. Real value is 1.
# Predicted a 1. Real value is 1.
# Predicted a 1. Real value is 1.
# Predicted a 1. Real value is 1.
# Predicted a 2. Real value is 2.
# Predicted a 2. Real value is 2.
# Predicted a 2. Real value is 2.
# Predicted a 2. Real value is 2.
# Predicted a 2. Real value is 2.
# Predicted a 3. Real value is 3.
# Predicted a 3. Real value is 3.
# Predicted a 3. Real value is 3.
# Predicted a 3. Real value is 3.
# Predicted a 3. Real value is 3.
# Predicted a 4. Real value is 4.
# Predicted a 4. Real value is 4.
# Predicted a 4. Real value is 4.
# Predicted a 4. Real value is 4.
# Predicted a 4. Real value is 4.
# Predicted a 5. Real value is 5.
# Predicted a 5. Real value is 5.
# Predicted a 5. Real value is 5.
# Predicted a 5. Real value is 5.
# Predicted a 5. Real value is 5.
# Predicted a 6. Real value is 6.
# Predicted a 6. Real value is 6.
# Predicted a 6. Real value is 6.
# Predicted a 6. Real value is 6.
# Predicted a 6. Real value is 6.
# Predicted a 47. Real value is 7.
# Predicted a 7. Real value is 7.
# Predicted a 7. Real value is 7.
# Predicted a 7. Real value is 7.
# Predicted a 7. Real value is 7.
# Predicted a 8. Real value is 8.
# Predicted a 8. Real value is 8.
# Predicted a 8. Real value is 8.
# Predicted a 8. Real value is 8.
# Predicted a 8. Real value is 8.
# Predicted a 9. Real value is 9.
# Predicted a 9. Real value is 9.
# Predicted a 9. Real value is 9.
# Predicted a 9. Real value is 9.
# Predicted a 9. Real value is 9.
# Predicted a 10. Real value is 10.
# Predicted a 10. Real value is 10.
# Predicted a 10. Real value is 10.
# Predicted a 159. Real value is 10.
# Predicted a 10. Real value is 10.
# Predicted a 11. Real value is 11.
# Predicted a 11. Real value is 11.
# Predicted a 11. Real value is 11.
# Predicted a 11. Real value is 11.
# Predicted a 11. Real value is 11.
# Predicted a 12. Real value is 12.
# Predicted a 12. Real value is 12.
# Predicted a 12. Real value is 12.
# Predicted a 12. Real value is 12.
# Predicted a 12. Real value is 12.
# Predicted a 13. Real value is 13.
# Predicted a 13. Real value is 13.
# Predicted a 13. Real value is 13.
# Predicted a 13. Real value is 13.
# Predicted a 13. Real value is 13.
# Predicted a 14. Real value is 14.
# Predicted a 14. Real value is 14.
# Predicted a 14. Real value is 14.
# Predicted a 14. Real value is 14.
# Predicted a 14. Real value is 14.
# Predicted a 15. Real value is 15.
# Predicted a 15. Real value is 15.
# Predicted a 15. Real value is 15.
# Predicted a 15. Real value is 15.
# Predicted a 15. Real value is 15.
# Predicted a 16. Real value is 16.
# Predicted a 16. Real value is 16.
# Predicted a 16. Real value is 16.
# Predicted a 16. Real value is 16.
# Predicted a 16. Real value is 16.
# Predicted a 17. Real value is 17.
# Predicted a 17. Real value is 17.
# Predicted a 17. Real value is 17.
# Predicted a 17. Real value is 17.
# Predicted a 17. Real value is 17.
# Predicted a 18. Real value is 18.
# Predicted a 18. Real value is 18.
# Predicted a 18. Real value is 18.
# Predicted a 18. Real value is 18.
# Predicted a 18. Real value is 18.
# Predicted a 19. Real value is 19.
# Predicted a 19. Real value is 19.
# Predicted a 19. Real value is 19.
# Predicted a 19. Real value is 19.
# Predicted a 19. Real value is 19.
# Predicted a 20. Real value is 20.
# Predicted a 20. Real value is 20.
# Predicted a 20. Real value is 20.
# Predicted a 20. Real value is 20.
# Predicted a 20. Real value is 20.
# Predicted a 21. Real value is 21.
# Predicted a 21. Real value is 21.
# Predicted a 21. Real value is 21.
# Predicted a 21. Real value is 21.
# Predicted a 21. Real value is 21.
# Predicted a 22. Real value is 22.
# Predicted a 209. Real value is 22.
# Predicted a 22. Real value is 22.
# Predicted a 22. Real value is 22.
# Predicted a 22. Real value is 22.
# Predicted a 23. Real value is 23.
# Predicted a 23. Real value is 23.
# Predicted a 23. Real value is 23.
# Predicted a 23. Real value is 23.
# Predicted a 23. Real value is 23.
# Predicted a 24. Real value is 24.
# Predicted a 24. Real value is 24.
# Predicted a 24. Real value is 24.
# Predicted a 24. Real value is 24.
# Predicted a 24. Real value is 24.
# Predicted a 25. Real value is 25.
# Predicted a 25. Real value is 25.
# Predicted a 25. Real value is 25.
# Predicted a 7. Real value is 25.
# Predicted a 25. Real value is 25.
# Predicted a 26. Real value is 26.
# Predicted a 26. Real value is 26.
# Predicted a 26. Real value is 26.
# Predicted a 26. Real value is 26.
# Predicted a 72. Real value is 26.
# Predicted a 27. Real value is 27.
# Predicted a 27. Real value is 27.
# Predicted a 27. Real value is 27.
# Predicted a 27. Real value is 27.
# Predicted a 27. Real value is 27.
# Predicted a 153. Real value is 28.
# Predicted a 28. Real value is 28.
# Predicted a 28. Real value is 28.
# Predicted a 28. Real value is 28.
# Predicted a 28. Real value is 28.
# Predicted a 29. Real value is 29.
# Predicted a 29. Real value is 29.
# Predicted a 29. Real value is 29.
# Predicted a 29. Real value is 29.
# Predicted a 29. Real value is 29.
# Predicted a 30. Real value is 30.
# Predicted a 30. Real value is 30.
# Predicted a 30. Real value is 30.
# Predicted a 30. Real value is 30.
# Predicted a 30. Real value is 30.
# Predicted a 31. Real value is 31.
# Predicted a 31. Real value is 31.
# Predicted a 31. Real value is 31.
# Predicted a 31. Real value is 31.
# Predicted a 31. Real value is 31.
# Predicted a 32. Real value is 32.
# Predicted a 32. Real value is 32.
# Predicted a 32. Real value is 32.
# Predicted a 32. Real value is 32.
# Predicted a 32. Real value is 32.
# Predicted a 33. Real value is 33.
# Predicted a 33. Real value is 33.
# Predicted a 33. Real value is 33.
# Predicted a 33. Real value is 33.
# Predicted a 33. Real value is 33.
# Predicted a 34. Real value is 34.
# Predicted a 34. Real value is 34.
# Predicted a 34. Real value is 34.
# Predicted a 34. Real value is 34.
# Predicted a 34. Real value is 34.
# Predicted a 35. Real value is 35.
# Predicted a 35. Real value is 35.
# Predicted a 35. Real value is 35.
# Predicted a 35. Real value is 35.
# Predicted a 35. Real value is 35.
# Predicted a 36. Real value is 36.
# Predicted a 36. Real value is 36.
# Predicted a 36. Real value is 36.
# Predicted a 36. Real value is 36.
# Predicted a 36. Real value is 36.
# Predicted a 37. Real value is 37.
# Predicted a 37. Real value is 37.
# Predicted a 97. Real value is 37.
# Predicted a 37. Real value is 37.
# Predicted a 37. Real value is 37.
# Predicted a 38. Real value is 38.
# Predicted a 38. Real value is 38.
# Predicted a 38. Real value is 38.
# Predicted a 38. Real value is 38.
# Predicted a 38. Real value is 38.
# Predicted a 39. Real value is 39.
# Predicted a 39. Real value is 39.
# Predicted a 39. Real value is 39.
# Predicted a 39. Real value is 39.
# Predicted a 39. Real value is 39.
# Predicted a 40. Real value is 40.
# Predicted a 40. Real value is 40.
# Predicted a 40. Real value is 40.
# Predicted a 40. Real value is 40.
# Predicted a 40. Real value is 40.
# Predicted a 41. Real value is 41.
# Predicted a 41. Real value is 41.
# Predicted a 41. Real value is 41.
# Predicted a 41. Real value is 41.
# Predicted a 41. Real value is 41.
# Predicted a 42. Real value is 42.
# Predicted a 42. Real value is 42.
# Predicted a 42. Real value is 42.
# Predicted a 42. Real value is 42.
# Predicted a 42. Real value is 42.
# Predicted a 43. Real value is 43.
# Predicted a 43. Real value is 43.
# Predicted a 43. Real value is 43.
# Predicted a 43. Real value is 43.
# Predicted a 43. Real value is 43.
# Predicted a 44. Real value is 44.
# Predicted a 44. Real value is 44.
# Predicted a 44. Real value is 44.
# Predicted a 152. Real value is 44.
# Predicted a 44. Real value is 44.
# Predicted a 2. Real value is 45.
# Predicted a 45. Real value is 45.
# Predicted a 45. Real value is 45.
# Predicted a 45. Real value is 45.
# Predicted a 45. Real value is 45.
# Predicted a 46. Real value is 46.
# Predicted a 46. Real value is 46.
# Predicted a 46. Real value is 46.
# Predicted a 46. Real value is 46.
# Predicted a 46. Real value is 46.
# Predicted a 47. Real value is 47.
# Predicted a 47. Real value is 47.
# Predicted a 47. Real value is 47.
# Predicted a 47. Real value is 47.
# Predicted a 47. Real value is 47.
# Predicted a 48. Real value is 48.
# Predicted a 48. Real value is 48.
# Predicted a 48. Real value is 48.
# Predicted a 48. Real value is 48.
# Predicted a 48. Real value is 48.
# Predicted a 49. Real value is 49.
# Predicted a 49. Real value is 49.
# Predicted a 49. Real value is 49.
# Predicted a 49. Real value is 49.
# Predicted a 49. Real value is 49.
# Predicted a 50. Real value is 50.
# Predicted a 50. Real value is 50.
# Predicted a 50. Real value is 50.
# Predicted a 50. Real value is 50.
# Predicted a 50. Real value is 50.
# Predicted a 51. Real value is 51.
# Predicted a 51. Real value is 51.
# Predicted a 51. Real value is 51.
# Predicted a 51. Real value is 51.
# Predicted a 51. Real value is 51.
# Predicted a 52. Real value is 52.
# Predicted a 52. Real value is 52.
# Predicted a 52. Real value is 52.
# Predicted a 52. Real value is 52.
# Predicted a 52. Real value is 52.
# Predicted a 53. Real value is 53.
# Predicted a 53. Real value is 53.
# Predicted a 53. Real value is 53.
# Predicted a 53. Real value is 53.
# Predicted a 53. Real value is 53.
# Predicted a 54. Real value is 54.
# Predicted a 54. Real value is 54.
# Predicted a 54. Real value is 54.
# Predicted a 54. Real value is 54.
# Predicted a 122. Real value is 54.
# Predicted a 55. Real value is 55.
# Predicted a 55. Real value is 55.
# Predicted a 55. Real value is 55.
# Predicted a 55. Real value is 55.
# Predicted a 55. Real value is 55.
# Predicted a 56. Real value is 56.
# Predicted a 56. Real value is 56.
# Predicted a 56. Real value is 56.
# Predicted a 56. Real value is 56.
# Predicted a 56. Real value is 56.
# Predicted a 57. Real value is 57.
# Predicted a 57. Real value is 57.
# Predicted a 57. Real value is 57.
# Predicted a 57. Real value is 57.
# Predicted a 57. Real value is 57.
# Predicted a 58. Real value is 58.
# Predicted a 58. Real value is 58.
# Predicted a 58. Real value is 58.
# Predicted a 58. Real value is 58.
# Predicted a 58. Real value is 58.
# Predicted a 59. Real value is 59.
# Predicted a 59. Real value is 59.
# Predicted a 59. Real value is 59.
# Predicted a 59. Real value is 59.
# Predicted a 59. Real value is 59.
# Predicted a 60. Real value is 60.
# Predicted a 60. Real value is 60.
# Predicted a 60. Real value is 60.
# Predicted a 60. Real value is 60.
# Predicted a 60. Real value is 60.
# Predicted a 61. Real value is 61.
# Predicted a 61. Real value is 61.
# Predicted a 61. Real value is 61.
# Predicted a 61. Real value is 61.
# Predicted a 61. Real value is 61.
# Predicted a 62. Real value is 62.
# Predicted a 62. Real value is 62.
# Predicted a 62. Real value is 62.
# Predicted a 62. Real value is 62.
# Predicted a 62. Real value is 62.
# Predicted a 63. Real value is 63.
# Predicted a 63. Real value is 63.
# Predicted a 63. Real value is 63.
# Predicted a 63. Real value is 63.
# Predicted a 63. Real value is 63.
# Predicted a 64. Real value is 64.
# Predicted a 64. Real value is 64.
# Predicted a 64. Real value is 64.
# Predicted a 64. Real value is 64.
# Predicted a 64. Real value is 64.
# Predicted a 65. Real value is 65.
# Predicted a 65. Real value is 65.
# Predicted a 65. Real value is 65.
# Predicted a 65. Real value is 65.
# Predicted a 65. Real value is 65.
# Predicted a 66. Real value is 66.
# Predicted a 66. Real value is 66.
# Predicted a 66. Real value is 66.
# Predicted a 66. Real value is 66.
# Predicted a 66. Real value is 66.
# Predicted a 67. Real value is 67.
# Predicted a 67. Real value is 67.
# Predicted a 67. Real value is 67.
# Predicted a 67. Real value is 67.
# Predicted a 67. Real value is 67.
# Predicted a 226. Real value is 68.
# Predicted a 226. Real value is 68.
# Predicted a 68. Real value is 68.
# Predicted a 68. Real value is 68.
# Predicted a 68. Real value is 68.
# Predicted a 69. Real value is 69.
# Predicted a 69. Real value is 69.
# Predicted a 69. Real value is 69.
# Predicted a 69. Real value is 69.
# Predicted a 69. Real value is 69.
# Predicted a 70. Real value is 70.
# Predicted a 70. Real value is 70.
# Predicted a 70. Real value is 70.
# Predicted a 70. Real value is 70.
# Predicted a 70. Real value is 70.
# Predicted a 71. Real value is 71.
# Predicted a 71. Real value is 71.
# Predicted a 71. Real value is 71.
# Predicted a 71. Real value is 71.
# Predicted a 71. Real value is 71.
# Predicted a 72. Real value is 72.
# Predicted a 72. Real value is 72.
# Predicted a 72. Real value is 72.
# Predicted a 72. Real value is 72.
# Predicted a 72. Real value is 72.
# Predicted a 73. Real value is 73.
# Predicted a 73. Real value is 73.
# Predicted a 73. Real value is 73.
# Predicted a 73. Real value is 73.
# Predicted a 73. Real value is 73.
# Predicted a 74. Real value is 74.
# Predicted a 74. Real value is 74.
# Predicted a 74. Real value is 74.
# Predicted a 74. Real value is 74.
# Predicted a 74. Real value is 74.
# Predicted a 75. Real value is 75.
# Predicted a 191. Real value is 75.
# Predicted a 75. Real value is 75.
# Predicted a 75. Real value is 75.
# Predicted a 75. Real value is 75.
# Predicted a 76. Real value is 76.
# Predicted a 76. Real value is 76.
# Predicted a 76. Real value is 76.
# Predicted a 76. Real value is 76.
# Predicted a 76. Real value is 76.
# Predicted a 77. Real value is 77.
# Predicted a 77. Real value is 77.
# Predicted a 77. Real value is 77.
# Predicted a 77. Real value is 77.
# Predicted a 77. Real value is 77.
# Predicted a 78. Real value is 78.
# Predicted a 78. Real value is 78.
# Predicted a 78. Real value is 78.
# Predicted a 78. Real value is 78.
# Predicted a 78. Real value is 78.
# Predicted a 79. Real value is 79.
# Predicted a 79. Real value is 79.
# Predicted a 79. Real value is 79.
# Predicted a 79. Real value is 79.
# Predicted a 79. Real value is 79.
# Predicted a 80. Real value is 80.
# Predicted a 80. Real value is 80.
# Predicted a 80. Real value is 80.
# Predicted a 80. Real value is 80.
# Predicted a 80. Real value is 80.
# Predicted a 81. Real value is 81.
# Predicted a 66. Real value is 81.
# Predicted a 81. Real value is 81.
# Predicted a 81. Real value is 81.
# Predicted a 81. Real value is 81.
# Predicted a 82. Real value is 82.
# Predicted a 82. Real value is 82.
# Predicted a 82. Real value is 82.
# Predicted a 82. Real value is 82.
# Predicted a 82. Real value is 82.
# Predicted a 83. Real value is 83.
# Predicted a 83. Real value is 83.
# Predicted a 164. Real value is 83.
# Predicted a 83. Real value is 83.
# Predicted a 83. Real value is 83.
# Predicted a 84. Real value is 84.
# Predicted a 84. Real value is 84.
# Predicted a 84. Real value is 84.
# Predicted a 84. Real value is 84.
# Predicted a 84. Real value is 84.
# Predicted a 85. Real value is 85.
# Predicted a 85. Real value is 85.
# Predicted a 85. Real value is 85.
# Predicted a 85. Real value is 85.
# Predicted a 85. Real value is 85.
# Predicted a 86. Real value is 86.
# Predicted a 86. Real value is 86.
# Predicted a 86. Real value is 86.
# Predicted a 86. Real value is 86.
# Predicted a 86. Real value is 86.
# Predicted a 87. Real value is 87.
# Predicted a 87. Real value is 87.
# Predicted a 87. Real value is 87.
# Predicted a 87. Real value is 87.
# Predicted a 87. Real value is 87.
# Predicted a 88. Real value is 88.
# Predicted a 88. Real value is 88.
# Predicted a 88. Real value is 88.
# Predicted a 88. Real value is 88.
# Predicted a 88. Real value is 88.
# Predicted a 89. Real value is 89.
# Predicted a 89. Real value is 89.
# Predicted a 89. Real value is 89.
# Predicted a 89. Real value is 89.
# Predicted a 89. Real value is 89.
# Predicted a 90. Real value is 90.
# Predicted a 90. Real value is 90.
# Predicted a 90. Real value is 90.
# Predicted a 90. Real value is 90.
# Predicted a 90. Real value is 90.
# Predicted a 91. Real value is 91.
# Predicted a 91. Real value is 91.
# Predicted a 103. Real value is 91.
# Predicted a 91. Real value is 91.
# Predicted a 91. Real value is 91.
# Predicted a 92. Real value is 92.
# Predicted a 188. Real value is 92.
# Predicted a 92. Real value is 92.
# Predicted a 92. Real value is 92.
# Predicted a 92. Real value is 92.
# Predicted a 154. Real value is 93.
# Predicted a 93. Real value is 93.
# Predicted a 93. Real value is 93.
# Predicted a 154. Real value is 93.
# Predicted a 93. Real value is 93.
# Predicted a 94. Real value is 94.
# Predicted a 94. Real value is 94.
# Predicted a 94. Real value is 94.
# Predicted a 94. Real value is 94.
# Predicted a 94. Real value is 94.
# Predicted a 103. Real value is 95.
# Predicted a 95. Real value is 95.
# Predicted a 95. Real value is 95.
# Predicted a 95. Real value is 95.
# Predicted a 95. Real value is 95.
# Predicted a 96. Real value is 96.
# Predicted a 96. Real value is 96.
# Predicted a 96. Real value is 96.
# Predicted a 96. Real value is 96.
# Predicted a 96. Real value is 96.
# Predicted a 97. Real value is 97.
# Predicted a 97. Real value is 97.
# Predicted a 97. Real value is 97.
# Predicted a 97. Real value is 97.
# Predicted a 97. Real value is 97.
# Predicted a 98. Real value is 98.
# Predicted a 98. Real value is 98.
# Predicted a 98. Real value is 98.
# Predicted a 98. Real value is 98.
# Predicted a 98. Real value is 98.
# Predicted a 99. Real value is 99.
# Predicted a 99. Real value is 99.
# Predicted a 99. Real value is 99.
# Predicted a 99. Real value is 99.
# Predicted a 99. Real value is 99.
# Predicted a 100. Real value is 100.
# Predicted a 100. Real value is 100.
# Predicted a 100. Real value is 100.
# Predicted a 100. Real value is 100.
# Predicted a 100. Real value is 100.
# Predicted a 101. Real value is 101.
# Predicted a 101. Real value is 101.
# Predicted a 101. Real value is 101.
# Predicted a 101. Real value is 101.
# Predicted a 101. Real value is 101.
# Predicted a 102. Real value is 102.
# Predicted a 102. Real value is 102.
# Predicted a 102. Real value is 102.
# Predicted a 102. Real value is 102.
# Predicted a 102. Real value is 102.
# Predicted a 103. Real value is 103.
# Predicted a 103. Real value is 103.
# Predicted a 103. Real value is 103.
# Predicted a 103. Real value is 103.
# Predicted a 103. Real value is 103.
# Predicted a 104. Real value is 104.
# Predicted a 104. Real value is 104.
# Predicted a 104. Real value is 104.
# Predicted a 104. Real value is 104.
# Predicted a 104. Real value is 104.
# Predicted a 105. Real value is 105.
# Predicted a 105. Real value is 105.
# Predicted a 105. Real value is 105.
# Predicted a 105. Real value is 105.
# Predicted a 105. Real value is 105.
# Predicted a 106. Real value is 106.
# Predicted a 106. Real value is 106.
# Predicted a 106. Real value is 106.
# Predicted a 106. Real value is 106.
# Predicted a 106. Real value is 106.
# Predicted a 107. Real value is 107.
# Predicted a 107. Real value is 107.
# Predicted a 107. Real value is 107.
# Predicted a 107. Real value is 107.
# Predicted a 107. Real value is 107.
# Predicted a 108. Real value is 108.
# Predicted a 108. Real value is 108.
# Predicted a 108. Real value is 108.
# Predicted a 108. Real value is 108.
# Predicted a 108. Real value is 108.
# Predicted a 109. Real value is 109.
# Predicted a 109. Real value is 109.
# Predicted a 109. Real value is 109.
# Predicted a 109. Real value is 109.
# Predicted a 109. Real value is 109.
# Predicted a 110. Real value is 110.
# Predicted a 110. Real value is 110.
# Predicted a 110. Real value is 110.
# Predicted a 110. Real value is 110.
# Predicted a 110. Real value is 110.
# Predicted a 111. Real value is 111.
# Predicted a 111. Real value is 111.
# Predicted a 111. Real value is 111.
# Predicted a 111. Real value is 111.
# Predicted a 111. Real value is 111.
# Predicted a 112. Real value is 112.
# Predicted a 112. Real value is 112.
# Predicted a 112. Real value is 112.
# Predicted a 112. Real value is 112.
# Predicted a 112. Real value is 112.
# Predicted a 113. Real value is 113.
# Predicted a 113. Real value is 113.
# Predicted a 113. Real value is 113.
# Predicted a 113. Real value is 113.
# Predicted a 113. Real value is 113.
# Predicted a 114. Real value is 114.
# Predicted a 114. Real value is 114.
# Predicted a 114. Real value is 114.
# Predicted a 114. Real value is 114.
# Predicted a 114. Real value is 114.
# Predicted a 115. Real value is 115.
# Predicted a 115. Real value is 115.
# Predicted a 115. Real value is 115.
# Predicted a 115. Real value is 115.
# Predicted a 115. Real value is 115.
# Predicted a 116. Real value is 116.
# Predicted a 116. Real value is 116.
# Predicted a 116. Real value is 116.
# Predicted a 116. Real value is 116.
# Predicted a 116. Real value is 116.
# Predicted a 117. Real value is 117.
# Predicted a 117. Real value is 117.
# Predicted a 117. Real value is 117.
# Predicted a 117. Real value is 117.
# Predicted a 117. Real value is 117.
# Predicted a 118. Real value is 118.
# Predicted a 118. Real value is 118.
# Predicted a 118. Real value is 118.
# Predicted a 118. Real value is 118.
# Predicted a 57. Real value is 118.
# Predicted a 119. Real value is 119.
# Predicted a 119. Real value is 119.
# Predicted a 119. Real value is 119.
# Predicted a 119. Real value is 119.
# Predicted a 119. Real value is 119.
# Predicted a 120. Real value is 120.
# Predicted a 120. Real value is 120.
# Predicted a 120. Real value is 120.
# Predicted a 120. Real value is 120.
# Predicted a 120. Real value is 120.
# Predicted a 121. Real value is 121.
# Predicted a 121. Real value is 121.
# Predicted a 176. Real value is 121.
# Predicted a 121. Real value is 121.
# Predicted a 121. Real value is 121.
# Predicted a 122. Real value is 122.
# Predicted a 122. Real value is 122.
# Predicted a 122. Real value is 122.
# Predicted a 122. Real value is 122.
# Predicted a 122. Real value is 122.
# Predicted a 133. Real value is 123.
# Predicted a 123. Real value is 123.
# Predicted a 119. Real value is 123.
# Predicted a 165. Real value is 123.
# Predicted a 123. Real value is 123.
# Predicted a 124. Real value is 124.
# Predicted a 124. Real value is 124.
# Predicted a 124. Real value is 124.
# Predicted a 124. Real value is 124.
# Predicted a 124. Real value is 124.
# Predicted a 125. Real value is 125.
# Predicted a 125. Real value is 125.
# Predicted a 125. Real value is 125.
# Predicted a 125. Real value is 125.
# Predicted a 125. Real value is 125.
# Predicted a 126. Real value is 126.
# Predicted a 126. Real value is 126.
# Predicted a 126. Real value is 126.
# Predicted a 126. Real value is 126.
# Predicted a 126. Real value is 126.
# Predicted a 127. Real value is 127.
# Predicted a 127. Real value is 127.
# Predicted a 127. Real value is 127.
# Predicted a 127. Real value is 127.
# Predicted a 127. Real value is 127.
# Predicted a 128. Real value is 128.
# Predicted a 128. Real value is 128.
# Predicted a 128. Real value is 128.
# Predicted a 128. Real value is 128.
# Predicted a 128. Real value is 128.
# Predicted a 129. Real value is 129.
# Predicted a 129. Real value is 129.
# Predicted a 129. Real value is 129.
# Predicted a 129. Real value is 129.
# Predicted a 129. Real value is 129.
# Predicted a 130. Real value is 130.
# Predicted a 130. Real value is 130.
# Predicted a 130. Real value is 130.
# Predicted a 130. Real value is 130.
# Predicted a 130. Real value is 130.
# Predicted a 131. Real value is 131.
# Predicted a 131. Real value is 131.
# Predicted a 131. Real value is 131.
# Predicted a 131. Real value is 131.
# Predicted a 131. Real value is 131.
# Predicted a 132. Real value is 132.
# Predicted a 132. Real value is 132.
# Predicted a 132. Real value is 132.
# Predicted a 132. Real value is 132.
# Predicted a 132. Real value is 132.
# Predicted a 133. Real value is 133.
# Predicted a 133. Real value is 133.
# Predicted a 133. Real value is 133.
# Predicted a 133. Real value is 133.
# Predicted a 133. Real value is 133.
# Predicted a 134. Real value is 134.
# Predicted a 134. Real value is 134.
# Predicted a 134. Real value is 134.
# Predicted a 134. Real value is 134.
# Predicted a 134. Real value is 134.
# Predicted a 135. Real value is 135.
# Predicted a 135. Real value is 135.
# Predicted a 205. Real value is 135.
# Predicted a 135. Real value is 135.
# Predicted a 135. Real value is 135.
# Predicted a 136. Real value is 136.
# Predicted a 136. Real value is 136.
# Predicted a 136. Real value is 136.
# Predicted a 136. Real value is 136.
# Predicted a 136. Real value is 136.
# Predicted a 137. Real value is 137.
# Predicted a 137. Real value is 137.
# Predicted a 137. Real value is 137.
# Predicted a 137. Real value is 137.
# Predicted a 137. Real value is 137.
# Predicted a 189. Real value is 138.
# Predicted a 138. Real value is 138.
# Predicted a 138. Real value is 138.
# Predicted a 138. Real value is 138.
# Predicted a 138. Real value is 138.
# Predicted a 139. Real value is 139.
# Predicted a 139. Real value is 139.
# Predicted a 139. Real value is 139.
# Predicted a 139. Real value is 139.
# Predicted a 139. Real value is 139.
# Predicted a 140. Real value is 140.
# Predicted a 140. Real value is 140.
# Predicted a 140. Real value is 140.
# Predicted a 140. Real value is 140.
# Predicted a 140. Real value is 140.
# Predicted a 141. Real value is 141.
# Predicted a 141. Real value is 141.
# Predicted a 141. Real value is 141.
# Predicted a 141. Real value is 141.
# Predicted a 141. Real value is 141.
# Predicted a 142. Real value is 142.
# Predicted a 142. Real value is 142.
# Predicted a 142. Real value is 142.
# Predicted a 142. Real value is 142.
# Predicted a 142. Real value is 142.
# Predicted a 143. Real value is 143.
# Predicted a 143. Real value is 143.
# Predicted a 143. Real value is 143.
# Predicted a 143. Real value is 143.
# Predicted a 143. Real value is 143.
# Predicted a 144. Real value is 144.
# Predicted a 144. Real value is 144.
# Predicted a 144. Real value is 144.
# Predicted a 144. Real value is 144.
# Predicted a 144. Real value is 144.
# Predicted a 145. Real value is 145.
# Predicted a 145. Real value is 145.
# Predicted a 145. Real value is 145.
# Predicted a 145. Real value is 145.
# Predicted a 145. Real value is 145.
# Predicted a 146. Real value is 146.
# Predicted a 146. Real value is 146.
# Predicted a 146. Real value is 146.
# Predicted a 146. Real value is 146.
# Predicted a 146. Real value is 146.
# Predicted a 147. Real value is 147.
# Predicted a 147. Real value is 147.
# Predicted a 147. Real value is 147.
# Predicted a 147. Real value is 147.
# Predicted a 147. Real value is 147.
# Predicted a 148. Real value is 148.
# Predicted a 148. Real value is 148.
# Predicted a 148. Real value is 148.
# Predicted a 148. Real value is 148.
# Predicted a 148. Real value is 148.
# Predicted a 149. Real value is 149.
# Predicted a 149. Real value is 149.
# Predicted a 149. Real value is 149.
# Predicted a 149. Real value is 149.
# Predicted a 149. Real value is 149.
# Predicted a 150. Real value is 150.
# Predicted a 150. Real value is 150.
# Predicted a 150. Real value is 150.
# Predicted a 150. Real value is 150.
# Predicted a 150. Real value is 150.
# Predicted a 151. Real value is 151.
# Predicted a 151. Real value is 151.
# Predicted a 151. Real value is 151.
# Predicted a 151. Real value is 151.
# Predicted a 151. Real value is 151.
# Predicted a 152. Real value is 152.
# Predicted a 152. Real value is 152.
# Predicted a 152. Real value is 152.
# Predicted a 152. Real value is 152.
# Predicted a 152. Real value is 152.
# Predicted a 153. Real value is 153.
# Predicted a 153. Real value is 153.
# Predicted a 1. Real value is 153.
# Predicted a 153. Real value is 153.
# Predicted a 153. Real value is 153.
# Predicted a 154. Real value is 154.
# Predicted a 154. Real value is 154.
# Predicted a 154. Real value is 154.
# Predicted a 154. Real value is 154.
# Predicted a 154. Real value is 154.
# Predicted a 155. Real value is 155.
# Predicted a 155. Real value is 155.
# Predicted a 155. Real value is 155.
# Predicted a 155. Real value is 155.
# Predicted a 155. Real value is 155.
# Predicted a 111. Real value is 156.
# Predicted a 156. Real value is 156.
# Predicted a 156. Real value is 156.
# Predicted a 156. Real value is 156.
# Predicted a 156. Real value is 156.
# Predicted a 157. Real value is 157.
# Predicted a 157. Real value is 157.
# Predicted a 157. Real value is 157.
# Predicted a 157. Real value is 157.
# Predicted a 157. Real value is 157.
# Predicted a 158. Real value is 158.
# Predicted a 158. Real value is 158.
# Predicted a 158. Real value is 158.
# Predicted a 158. Real value is 158.
# Predicted a 65. Real value is 158.
# Predicted a 159. Real value is 159.
# Predicted a 159. Real value is 159.
# Predicted a 159. Real value is 159.
# Predicted a 159. Real value is 159.
# Predicted a 159. Real value is 159.
# Predicted a 160. Real value is 160.
# Predicted a 160. Real value is 160.
# Predicted a 160. Real value is 160.
# Predicted a 160. Real value is 160.
# Predicted a 160. Real value is 160.
# Predicted a 66. Real value is 161.
# Predicted a 161. Real value is 161.
# Predicted a 244. Real value is 161.
# Predicted a 161. Real value is 161.
# Predicted a 161. Real value is 161.
# Predicted a 162. Real value is 162.
# Predicted a 162. Real value is 162.
# Predicted a 162. Real value is 162.
# Predicted a 162. Real value is 162.
# Predicted a 162. Real value is 162.
# Predicted a 163. Real value is 163.
# Predicted a 163. Real value is 163.
# Predicted a 163. Real value is 163.
# Predicted a 163. Real value is 163.
# Predicted a 163. Real value is 163.
# Predicted a 164. Real value is 164.
# Predicted a 164. Real value is 164.
# Predicted a 164. Real value is 164.
# Predicted a 164. Real value is 164.
# Predicted a 164. Real value is 164.
# Predicted a 165. Real value is 165.
# Predicted a 165. Real value is 165.
# Predicted a 165. Real value is 165.
# Predicted a 165. Real value is 165.
# Predicted a 165. Real value is 165.
# Predicted a 166. Real value is 166.
# Predicted a 166. Real value is 166.
# Predicted a 166. Real value is 166.
# Predicted a 166. Real value is 166.
# Predicted a 166. Real value is 166.
# Predicted a 167. Real value is 167.
# Predicted a 167. Real value is 167.
# Predicted a 167. Real value is 167.
# Predicted a 167. Real value is 167.
# Predicted a 167. Real value is 167.
# Predicted a 168. Real value is 168.
# Predicted a 168. Real value is 168.
# Predicted a 168. Real value is 168.
# Predicted a 168. Real value is 168.
# Predicted a 168. Real value is 168.
# Predicted a 169. Real value is 169.
# Predicted a 169. Real value is 169.
# Predicted a 169. Real value is 169.
# Predicted a 169. Real value is 169.
# Predicted a 169. Real value is 169.
# Predicted a 170. Real value is 170.
# Predicted a 170. Real value is 170.
# Predicted a 170. Real value is 170.
# Predicted a 170. Real value is 170.
# Predicted a 170. Real value is 170.
# Predicted a 171. Real value is 171.
# Predicted a 171. Real value is 171.
# Predicted a 171. Real value is 171.
# Predicted a 171. Real value is 171.
# Predicted a 171. Real value is 171.
# Predicted a 172. Real value is 172.
# Predicted a 172. Real value is 172.
# Predicted a 172. Real value is 172.
# Predicted a 172. Real value is 172.
# Predicted a 172. Real value is 172.
# Predicted a 173. Real value is 173.
# Predicted a 173. Real value is 173.
# Predicted a 173. Real value is 173.
# Predicted a 173. Real value is 173.
# Predicted a 173. Real value is 173.
# Predicted a 174. Real value is 174.
# Predicted a 174. Real value is 174.
# Predicted a 174. Real value is 174.
# Predicted a 174. Real value is 174.
# Predicted a 174. Real value is 174.
# Predicted a 175. Real value is 175.
# Predicted a 175. Real value is 175.
# Predicted a 175. Real value is 175.
# Predicted a 175. Real value is 175.
# Predicted a 175. Real value is 175.
# Predicted a 176. Real value is 176.
# Predicted a 241. Real value is 176.
# Predicted a 176. Real value is 176.
# Predicted a 176. Real value is 176.
# Predicted a 176. Real value is 176.
# Predicted a 177. Real value is 177.
# Predicted a 177. Real value is 177.
# Predicted a 177. Real value is 177.
# Predicted a 177. Real value is 177.
# Predicted a 177. Real value is 177.
# Predicted a 178. Real value is 178.
# Predicted a 60. Real value is 178.
# Predicted a 178. Real value is 178.
# Predicted a 178. Real value is 178.
# Predicted a 178. Real value is 178.
# Predicted a 130. Real value is 179.
# Predicted a 223. Real value is 179.
# Predicted a 179. Real value is 179.
# Predicted a 179. Real value is 179.
# Predicted a 179. Real value is 179.
# Predicted a 180. Real value is 180.
# Predicted a 180. Real value is 180.
# Predicted a 180. Real value is 180.
# Predicted a 180. Real value is 180.
# Predicted a 180. Real value is 180.
# Predicted a 181. Real value is 181.
# Predicted a 181. Real value is 181.
# Predicted a 181. Real value is 181.
# Predicted a 181. Real value is 181.
# Predicted a 181. Real value is 181.
# Predicted a 182. Real value is 182.
# Predicted a 182. Real value is 182.
# Predicted a 182. Real value is 182.
# Predicted a 182. Real value is 182.
# Predicted a 182. Real value is 182.
# Predicted a 183. Real value is 183.
# Predicted a 183. Real value is 183.
# Predicted a 183. Real value is 183.
# Predicted a 183. Real value is 183.
# Predicted a 183. Real value is 183.
# Predicted a 184. Real value is 184.
# Predicted a 184. Real value is 184.
# Predicted a 184. Real value is 184.
# Predicted a 184. Real value is 184.
# Predicted a 184. Real value is 184.
# Predicted a 185. Real value is 185.
# Predicted a 185. Real value is 185.
# Predicted a 185. Real value is 185.
# Predicted a 185. Real value is 185.
# Predicted a 185. Real value is 185.
# Predicted a 186. Real value is 186.
# Predicted a 186. Real value is 186.
# Predicted a 186. Real value is 186.
# Predicted a 186. Real value is 186.
# Predicted a 186. Real value is 186.
# Predicted a 187. Real value is 187.
# Predicted a 187. Real value is 187.
# Predicted a 187. Real value is 187.
# Predicted a 187. Real value is 187.
# Predicted a 187. Real value is 187.
# Predicted a 188. Real value is 188.
# Predicted a 188. Real value is 188.
# Predicted a 188. Real value is 188.
# Predicted a 188. Real value is 188.
# Predicted a 188. Real value is 188.
# Predicted a 189. Real value is 189.
# Predicted a 189. Real value is 189.
# Predicted a 189. Real value is 189.
# Predicted a 189. Real value is 189.
# Predicted a 189. Real value is 189.
# Predicted a 190. Real value is 190.
# Predicted a 190. Real value is 190.
# Predicted a 190. Real value is 190.
# Predicted a 190. Real value is 190.
# Predicted a 190. Real value is 190.
# Predicted a 191. Real value is 191.
# Predicted a 191. Real value is 191.
# Predicted a 191. Real value is 191.
# Predicted a 191. Real value is 191.
# Predicted a 191. Real value is 191.
# Predicted a 192. Real value is 192.
# Predicted a 192. Real value is 192.
# Predicted a 192. Real value is 192.
# Predicted a 192. Real value is 192.
# Predicted a 192. Real value is 192.
# Predicted a 193. Real value is 193.
# Predicted a 193. Real value is 193.
# Predicted a 193. Real value is 193.
# Predicted a 193. Real value is 193.
# Predicted a 193. Real value is 193.
# Predicted a 194. Real value is 194.
# Predicted a 194. Real value is 194.
# Predicted a 194. Real value is 194.
# Predicted a 194. Real value is 194.
# Predicted a 194. Real value is 194.
# Predicted a 195. Real value is 195.
# Predicted a 195. Real value is 195.
# Predicted a 195. Real value is 195.
# Predicted a 195. Real value is 195.
# Predicted a 195. Real value is 195.
# Predicted a 196. Real value is 196.
# Predicted a 196. Real value is 196.
# Predicted a 196. Real value is 196.
# Predicted a 196. Real value is 196.
# Predicted a 196. Real value is 196.
# Predicted a 197. Real value is 197.
# Predicted a 197. Real value is 197.
# Predicted a 197. Real value is 197.
# Predicted a 197. Real value is 197.
# Predicted a 197. Real value is 197.
# Predicted a 198. Real value is 198.
# Predicted a 198. Real value is 198.
# Predicted a 198. Real value is 198.
# Predicted a 198. Real value is 198.
# Predicted a 198. Real value is 198.
# Predicted a 199. Real value is 199.
# Predicted a 199. Real value is 199.
# Predicted a 199. Real value is 199.
# Predicted a 199. Real value is 199.
# Predicted a 199. Real value is 199.
# Predicted a 200. Real value is 200.
# Predicted a 200. Real value is 200.
# Predicted a 200. Real value is 200.
# Predicted a 200. Real value is 200.
# Predicted a 200. Real value is 200.
# Predicted a 201. Real value is 201.
# Predicted a 201. Real value is 201.
# Predicted a 201. Real value is 201.
# Predicted a 201. Real value is 201.
# Predicted a 201. Real value is 201.
# Predicted a 202. Real value is 202.
# Predicted a 202. Real value is 202.
# Predicted a 202. Real value is 202.
# Predicted a 202. Real value is 202.
# Predicted a 202. Real value is 202.
# Predicted a 203. Real value is 203.
# Predicted a 203. Real value is 203.
# Predicted a 203. Real value is 203.
# Predicted a 203. Real value is 203.
# Predicted a 203. Real value is 203.
# Predicted a 204. Real value is 204.
# Predicted a 204. Real value is 204.
# Predicted a 204. Real value is 204.
# Predicted a 204. Real value is 204.
# Predicted a 204. Real value is 204.
# Predicted a 205. Real value is 205.
# Predicted a 205. Real value is 205.
# Predicted a 205. Real value is 205.
# Predicted a 205. Real value is 205.
# Predicted a 205. Real value is 205.
# Predicted a 206. Real value is 206.
# Predicted a 21. Real value is 206.
# Predicted a 206. Real value is 206.
# Predicted a 206. Real value is 206.
# Predicted a 206. Real value is 206.
# Predicted a 207. Real value is 207.
# Predicted a 207. Real value is 207.
# Predicted a 207. Real value is 207.
# Predicted a 207. Real value is 207.
# Predicted a 207. Real value is 207.
# Predicted a 208. Real value is 208.
# Predicted a 208. Real value is 208.
# Predicted a 208. Real value is 208.
# Predicted a 208. Real value is 208.
# Predicted a 208. Real value is 208.
# Predicted a 209. Real value is 209.
# Predicted a 209. Real value is 209.
# Predicted a 209. Real value is 209.
# Predicted a 209. Real value is 209.
# Predicted a 209. Real value is 209.
# Predicted a 210. Real value is 210.
# Predicted a 210. Real value is 210.
# Predicted a 210. Real value is 210.
# Predicted a 210. Real value is 210.
# Predicted a 210. Real value is 210.
# Predicted a 211. Real value is 211.
# Predicted a 211. Real value is 211.
# Predicted a 211. Real value is 211.
# Predicted a 211. Real value is 211.
# Predicted a 211. Real value is 211.
# Predicted a 127. Real value is 212.
# Predicted a 212. Real value is 212.
# Predicted a 212. Real value is 212.
# Predicted a 212. Real value is 212.
# Predicted a 212. Real value is 212.
# Predicted a 9. Real value is 213.
# Predicted a 213. Real value is 213.
# Predicted a 213. Real value is 213.
# Predicted a 213. Real value is 213.
# Predicted a 213. Real value is 213.
# Predicted a 214. Real value is 214.
# Predicted a 214. Real value is 214.
# Predicted a 214. Real value is 214.
# Predicted a 214. Real value is 214.
# Predicted a 214. Real value is 214.
# Predicted a 215. Real value is 215.
# Predicted a 215. Real value is 215.
# Predicted a 215. Real value is 215.
# Predicted a 215. Real value is 215.
# Predicted a 215. Real value is 215.
# Predicted a 216. Real value is 216.
# Predicted a 216. Real value is 216.
# Predicted a 216. Real value is 216.
# Predicted a 216. Real value is 216.
# Predicted a 216. Real value is 216.
# Predicted a 217. Real value is 217.
# Predicted a 217. Real value is 217.
# Predicted a 217. Real value is 217.
# Predicted a 217. Real value is 217.
# Predicted a 217. Real value is 217.
# Predicted a 218. Real value is 218.
# Predicted a 218. Real value is 218.
# Predicted a 218. Real value is 218.
# Predicted a 218. Real value is 218.
# Predicted a 218. Real value is 218.
# Predicted a 219. Real value is 219.
# Predicted a 219. Real value is 219.
# Predicted a 219. Real value is 219.
# Predicted a 219. Real value is 219.
# Predicted a 219. Real value is 219.
# Predicted a 220. Real value is 220.
# Predicted a 220. Real value is 220.
# Predicted a 220. Real value is 220.
# Predicted a 220. Real value is 220.
# Predicted a 220. Real value is 220.
# Predicted a 221. Real value is 221.
# Predicted a 221. Real value is 221.
# Predicted a 221. Real value is 221.
# Predicted a 221. Real value is 221.
# Predicted a 221. Real value is 221.
# Predicted a 222. Real value is 222.
# Predicted a 222. Real value is 222.
# Predicted a 222. Real value is 222.
# Predicted a 222. Real value is 222.
# Predicted a 222. Real value is 222.
# Predicted a 223. Real value is 223.
# Predicted a 223. Real value is 223.
# Predicted a 223. Real value is 223.
# Predicted a 223. Real value is 223.
# Predicted a 223. Real value is 223.
# Predicted a 224. Real value is 224.
# Predicted a 224. Real value is 224.
# Predicted a 224. Real value is 224.
# Predicted a 224. Real value is 224.
# Predicted a 224. Real value is 224.
# Predicted a 225. Real value is 225.
# Predicted a 225. Real value is 225.
# Predicted a 225. Real value is 225.
# Predicted a 225. Real value is 225.
# Predicted a 225. Real value is 225.
# Predicted a 226. Real value is 226.
# Predicted a 226. Real value is 226.
# Predicted a 226. Real value is 226.
# Predicted a 226. Real value is 226.
# Predicted a 226. Real value is 226.
# Predicted a 227. Real value is 227.
# Predicted a 227. Real value is 227.
# Predicted a 227. Real value is 227.
# Predicted a 227. Real value is 227.
# Predicted a 227. Real value is 227.
# Predicted a 228. Real value is 228.
# Predicted a 228. Real value is 228.
# Predicted a 47. Real value is 228.
# Predicted a 228. Real value is 228.
# Predicted a 228. Real value is 228.
# Predicted a 229. Real value is 229.
# Predicted a 229. Real value is 229.
# Predicted a 229. Real value is 229.
# Predicted a 229. Real value is 229.
# Predicted a 127. Real value is 229.
# Predicted a 230. Real value is 230.
# Predicted a 230. Real value is 230.
# Predicted a 230. Real value is 230.
# Predicted a 230. Real value is 230.
# Predicted a 230. Real value is 230.
# Predicted a 231. Real value is 231.
# Predicted a 231. Real value is 231.
# Predicted a 231. Real value is 231.
# Predicted a 231. Real value is 231.
# Predicted a 231. Real value is 231.
# Predicted a 232. Real value is 232.
# Predicted a 232. Real value is 232.
# Predicted a 232. Real value is 232.
# Predicted a 232. Real value is 232.
# Predicted a 232. Real value is 232.
# Predicted a 233. Real value is 233.
# Predicted a 233. Real value is 233.
# Predicted a 233. Real value is 233.
# Predicted a 233. Real value is 233.
# Predicted a 233. Real value is 233.
# Predicted a 234. Real value is 234.
# Predicted a 234. Real value is 234.
# Predicted a 234. Real value is 234.
# Predicted a 234. Real value is 234.
# Predicted a 234. Real value is 234.
# Predicted a 235. Real value is 235.
# Predicted a 235. Real value is 235.
# Predicted a 235. Real value is 235.
# Predicted a 235. Real value is 235.
# Predicted a 235. Real value is 235.
# Predicted a 236. Real value is 236.
# Predicted a 236. Real value is 236.
# Predicted a 236. Real value is 236.
# Predicted a 236. Real value is 236.
# Predicted a 236. Real value is 236.
# Predicted a 237. Real value is 237.
# Predicted a 237. Real value is 237.
# Predicted a 237. Real value is 237.
# Predicted a 237. Real value is 237.
# Predicted a 237. Real value is 237.
# Predicted a 238. Real value is 238.
# Predicted a 238. Real value is 238.
# Predicted a 238. Real value is 238.
# Predicted a 238. Real value is 238.
# Predicted a 238. Real value is 238.
# Predicted a 239. Real value is 239.
# Predicted a 239. Real value is 239.
# Predicted a 239. Real value is 239.
# Predicted a 239. Real value is 239.
# Predicted a 239. Real value is 239.
# Predicted a 240. Real value is 240.
# Predicted a 240. Real value is 240.
# Predicted a 240. Real value is 240.
# Predicted a 240. Real value is 240.
# Predicted a 240. Real value is 240.
# Predicted a 241. Real value is 241.
# Predicted a 241. Real value is 241.
# Predicted a 241. Real value is 241.
# Predicted a 241. Real value is 241.
# Predicted a 241. Real value is 241.
# Predicted a 242. Real value is 242.
# Predicted a 242. Real value is 242.
# Predicted a 242. Real value is 242.
# Predicted a 242. Real value is 242.
# Predicted a 242. Real value is 242.
# Predicted a 243. Real value is 243.
# Predicted a 243. Real value is 243.
# Predicted a 243. Real value is 243.
# Predicted a 243. Real value is 243.
# Predicted a 243. Real value is 243.
# Predicted a 244. Real value is 244.
# Predicted a 244. Real value is 244.
# Predicted a 244. Real value is 244.
# Predicted a 244. Real value is 244.
# Predicted a 244. Real value is 244.
# Predicted a 245. Real value is 245.
# Predicted a 245. Real value is 245.
# Predicted a 245. Real value is 245.
# Predicted a 245. Real value is 245.
# Predicted a 245. Real value is 245.
# Predicted a 246. Real value is 246.
# Predicted a 246. Real value is 246.
# Predicted a 246. Real value is 246.
# Predicted a 246. Real value is 246.
# Predicted a 246. Real value is 246.
# Predicted a 247. Real value is 247.
# Predicted a 166. Real value is 247.
# Predicted a 247. Real value is 247.
# Predicted a 247. Real value is 247.
# Predicted a 247. Real value is 247.
# Predicted a 248. Real value is 248.
# Predicted a 248. Real value is 248.
# Predicted a 248. Real value is 248.
# Predicted a 248. Real value is 248.
# Predicted a 248. Real value is 248.
# Predicted a 249. Real value is 249.
# Predicted a 236. Real value is 249.
# Predicted a 249. Real value is 249.
# Predicted a 249. Real value is 249.
# Predicted a 249. Real value is 249.
